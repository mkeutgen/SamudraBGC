# %%
# Out:
# 2025-11-25 20:50:33,465 - INFO - Loading hist_control_cobalt_3d_yearly__2016_01.nc
# 2025-11-25 20:50:34,428 - INFO - Loading hist_control_dynamics3d_yearly__2016_01.nc
# 2025-11-25 20:50:34,444 - INFO - Loading hist_control_dynamics2d_yearly__2016_01.nc
# /scratch/cimes/maximek/INMOS/Ocean_Emulator/src/preprocess/preprocess_mom6dg_parallelized.py:471: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = xr.merge(datasets, join="inner")
# ...
